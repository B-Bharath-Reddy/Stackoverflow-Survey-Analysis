# %% [markdown]
# # Pandas Intro

# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv')

# %%
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
df.shape
# Out:
# (89184, 84)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89184 entries, 0 to 89183
# Data columns (total 84 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ResponseId                           89184 non-null  int64
#  1   Q120                                 89184 non-null  object
#  2   MainBranch                           89184 non-null  object
#  3   Age                                  89184 non-null  object
#  4   Employment                           87898 non-null  object
#  5   RemoteWork                           73810 non-null  object
#  6   CodingActivities                     73764 non-null  object
#  7   EdLevel                              87973 non-null  object
#  8   LearnCode                            87663 non-null  object
#  9   LearnCodeOnline                      70084 non-null  object
#  10  LearnCodeCoursesCert                 37076 non-null  object
# ...

# %%
pd.set_option('display.max_columns',84)

# %%
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
import pandas as pd
schema_df = pd.read_csv("survey_results_schema.csv")

# %%
schema_df
# Out:
#        qid        qname                                           question  \
# 0    QID16           S0  <div><span style="font-size:19px;"><strong>Hel...
# 1    QID12     MetaInfo                                  Browser Meta Info
# 2   QID310         Q310  <div><span style="font-size:19px;"><strong>You...
# 3   QID312         Q120
# 4     QID1           S1  <span style="font-size:22px; font-family: aria...
# ..     ...          ...                                                ...
# 73  QID289  Knowledge_7  Waiting on answers to questions often causes i...
# 74  QID289  Knowledge_8  I feel like I have the tools and/or resources ...
# 75  QID290  Frequency_1  Needing help from people outside of your immed...
# 76  QID290  Frequency_2  Interacting with people outside of your immedi...
# 77  QID290  Frequency_3  Encountering knowledge silos (where one indivi...
#
#    force_resp  type selector
# 0       False    DB       TB
# 1       False  Meta  Browser
# ...

# %%
pd.set_option('display.max_rows',85)

# %%
schema_df
# Out:
#        qid                 qname  \
# 0    QID16                    S0
# 1    QID12              MetaInfo
# 2   QID310                  Q310
# 3   QID312                  Q120
# 4     QID1                    S1
# 5     QID2            MainBranch
# 6   QID127                   Age
# 7   QID296            Employment
# 8   QID308            RemoteWork
# 9   QID297      CodingActivities
# 10  QID190                    S2
# 11   QID25               EdLevel
# 12  QID276             LearnCode
# 13  QID281       LearnCodeOnline
# 14  QID306  LearnCodeCoursesCert
# 15   QID32             YearsCode
# 16   QID34          YearsCodePro
# 17   QID31               DevType
# 18   QID29               OrgSize
# 19  QID278     PurchaseInfluence
# 20  QID322              TechList
# 21  QID279            BuyNewTool
# 22    QID6               Country
# 23   QID50              Currency
# 24   QID51             CompTotal
# 25   QID61                    S3
# 26  QID233              Language
# ...

# %%
df.head(10)
# Out:
#    ResponseId     Q120                                         MainBranch  \
# 0           1  I agree                                      None of these
# 1           2  I agree                     I am a developer by profession
# 2           3  I agree                     I am a developer by profession
# 3           4  I agree                     I am a developer by profession
# 4           5  I agree                     I am a developer by profession
# 5           6  I agree                     I am a developer by profession
# 6           7  I agree                     I am a developer by profession
# 7           8  I agree                     I am a developer by profession
# 8           9  I agree  I am not primarily a developer, but I write co...
# 9          10  I agree                     I am a developer by profession
#
#                Age                                         Employment  \
# 0  18-24 years old                                                NaN
# ...

# %%
df.tail(10)
# Out:
#        ResponseId     Q120                      MainBranch  \
# 89174       89175  I agree  I am a developer by profession
# 89175       89176  I agree  I am a developer by profession
# 89176       89177  I agree  I am a developer by profession
# 89177       89178  I agree  I am a developer by profession
# 89178       89179  I agree  I am a developer by profession
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 89174     18-24 years old                                Employed, full-time
# 89175     25-34 years old                                Employed, full-time
# 89176     18-24 years old                                 Student, full-time
# ...

# %%
schema_df.head(5)
# Out:
#       qid     qname                                           question  \
# 0   QID16        S0  <div><span style="font-size:19px;"><strong>Hel...
# 1   QID12  MetaInfo                                  Browser Meta Info
# 2  QID310      Q310  <div><span style="font-size:19px;"><strong>You...
# 3  QID312      Q120
# 4    QID1        S1  <span style="font-size:22px; font-family: aria...
#
#   force_resp  type selector
# 0      False    DB       TB
# 1      False  Meta  Browser
# 2      False    DB       TB
# 3       True    MC     SAVR
# 4      False    DB       TB

# %% [markdown]
# ### second video

# %% [markdown]
# ### Data Frames creation by using dictionary

# %% [markdown]
# - Basically a Data Frame is a rows and columns or data in rows and columns
#   or 2 dimensional data structure

# %%
df.columns
# Out:
# Index(['ResponseId', 'Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
# ...

# %%
df['Employment']
# Out:
# 0                                                      NaN
# 1                                      Employed, full-time
# 2                                      Employed, full-time
# 3                                      Employed, full-time
# 4        Employed, full-time;Independent contractor, fr...
#                                ...
# 89179    Employed, full-time;Independent contractor, fr...
# 89180               Student, full-time;Employed, part-time
# 89181                                  I prefer not to say
# 89182               Employed, part-time;Student, part-time
# 89183                                  Employed, full-time
# Name: Employment, Length: 89184, dtype: object

# %%
df.loc[[0,2],['Age','Employment']]
# Out:
#                Age           Employment
# 0  18-24 years old                  NaN
# 2  45-54 years old  Employed, full-time

# %%
df.loc[0:5,'Age':'LearnCode'] # slicing last value included
# Out:
#                Age                                         Employment  \
# 0  18-24 years old                                                NaN
# 1  25-34 years old                                Employed, full-time
# 2  45-54 years old                                Employed, full-time
# 3  25-34 years old                                Employed, full-time
# 4  25-34 years old  Employed, full-time;Independent contractor, fr...
# 5  35-44 years old                                Employed, full-time
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# 4                                Remote
# 5                                Remote
#
#                                     CodingActivities  \
# 0                                                NaN
# 1  Hobby;Contribute to open-source projects;Boots...
# ...

# %% [markdown]
# # Third Video

# %%
df.set_index('ResponseId',inplace=True)

# %%
df
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 1           I agree                   None of these     18-24 years old
# 2           I agree  I am a developer by profession     25-34 years old
# 3           I agree  I am a developer by profession     45-54 years old
# 4           I agree  I am a developer by profession     25-34 years old
# 5           I agree  I am a developer by profession     25-34 years old
# ...             ...                             ...                 ...
# 89180       I agree  I am a developer by profession     25-34 years old
# 89181       I agree  I am a developer by profession     18-24 years old
# 89182       I agree     I code primarily as a hobby   Prefer not to say
# 89183       I agree  I am a developer by profession  Under 18 years old
# 89184       I agree  I am a developer by profession     35-44 years old
#
#                                                    Employment  \
# ResponseId
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
df = pd.read_csv('survey_results_public.csv',index_col = 'ResponseId')

# %%
df
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 1           I agree                   None of these     18-24 years old
# 2           I agree  I am a developer by profession     25-34 years old
# 3           I agree  I am a developer by profession     45-54 years old
# 4           I agree  I am a developer by profession     25-34 years old
# 5           I agree  I am a developer by profession     25-34 years old
# ...             ...                             ...                 ...
# 89180       I agree  I am a developer by profession     25-34 years old
# 89181       I agree  I am a developer by profession     18-24 years old
# 89182       I agree     I code primarily as a hobby   Prefer not to say
# 89183       I agree  I am a developer by profession  Under 18 years old
# 89184       I agree  I am a developer by profession     35-44 years old
#
#                                                    Employment  \
# ResponseId
# ...

# %%
schema_df
# Out:
#        qid                 qname  \
# 0    QID16                    S0
# 1    QID12              MetaInfo
# 2   QID310                  Q310
# 3   QID312                  Q120
# 4     QID1                    S1
# 5     QID2            MainBranch
# 6   QID127                   Age
# 7   QID296            Employment
# 8   QID308            RemoteWork
# 9   QID297      CodingActivities
# 10  QID190                    S2
# 11   QID25               EdLevel
# 12  QID276             LearnCode
# 13  QID281       LearnCodeOnline
# 14  QID306  LearnCodeCoursesCert
# 15   QID32             YearsCode
# 16   QID34          YearsCodePro
# 17   QID31               DevType
# 18   QID29               OrgSize
# 19  QID278     PurchaseInfluence
# 20  QID322              TechList
# 21  QID279            BuyNewTool
# 22    QID6               Country
# 23   QID50              Currency
# 24   QID51             CompTotal
# 25   QID61                    S3
# 26  QID233              Language
# ...

# %%
schema_df.set_index('qname',inplace=True)

# %%
schema_df
# Out:
#                          qid  \
# qname
# S0                     QID16
# MetaInfo               QID12
# Q310                  QID310
# Q120                  QID312
# S1                      QID1
# MainBranch              QID2
# Age                   QID127
# Employment            QID296
# RemoteWork            QID308
# CodingActivities      QID297
# S2                    QID190
# EdLevel                QID25
# LearnCode             QID276
# LearnCodeOnline       QID281
# LearnCodeCoursesCert  QID306
# YearsCode              QID32
# YearsCodePro           QID34
# DevType                QID31
# OrgSize                QID29
# PurchaseInfluence     QID278
# TechList              QID322
# BuyNewTool            QID279
# Country                 QID6
# Currency               QID50
# CompTotal              QID51
# S3                     QID61
# Language              QID233
# Database              QID262
# Platform              QID263
# Webframe              QID264
# ...

# %%
schema_df.loc[['Age','Employment']]
# Out:
#                qid                                           question  \
# qname
# Age         QID127                                What is your age? *
# Employment  QID296  Which of the following best describes your cur...
#
#            force_resp type selector
# qname
# Age              True   MC     MAVR
# Employment      False   MC     MAVR

# %%
schema_df.loc['Age','question']
# Out:
# 'What is your age? *'

# %%
schema_df.sort_index(inplace=True)

# %%
schema_df
# Out:
#                          qid  \
# qname
# AIAcc                 QID324
# AIBen                 QID316
# AIDev                 QID328
# AINext                QID320
# AIOpen                QID321
# AISearch              QID327
# AISelect              QID314
# AISent                QID315
# AITool                QID319
# Age                   QID127
# BuyNewTool            QID279
# CodingActivities      QID297
# CompTotal              QID51
# Country                 QID6
# Currency               QID50
# Database              QID262
# DevType                QID31
# EdLevel                QID25
# Employment            QID296
# Frequency             QID290
# Frequency_1           QID290
# Frequency_2           QID290
# Frequency_3           QID290
# ICorPM                QID287
# Industry              QID326
# Knowledge             QID289
# Knowledge_1           QID289
# Knowledge_2           QID289
# Knowledge_3           QID289
# Knowledge_4           QID289
# ...

# %% [markdown]
# # Filtering

# %%
schema_df
# Out:
#                          qid  \
# qname
# AIAcc                 QID324
# AIBen                 QID316
# AIDev                 QID328
# AINext                QID320
# AIOpen                QID321
# AISearch              QID327
# AISelect              QID314
# AISent                QID315
# AITool                QID319
# Age                   QID127
# BuyNewTool            QID279
# CodingActivities      QID297
# CompTotal              QID51
# Country                 QID6
# Currency               QID50
# Database              QID262
# DevType                QID31
# EdLevel                QID25
# Employment            QID296
# Frequency             QID290
# Frequency_1           QID290
# Frequency_2           QID290
# Frequency_3           QID290
# ICorPM                QID287
# Industry              QID326
# Knowledge             QID289
# Knowledge_1           QID289
# Knowledge_2           QID289
# Knowledge_3           QID289
# Knowledge_4           QID289
# ...

# %%
high_salary=(df['CompTotal'] > 70000)

# %%
df.loc[high_salary] # ['Country','LanguageHaveWorkedWith']
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 2           I agree  I am a developer by profession  25-34 years old
# 3           I agree  I am a developer by profession  45-54 years old
# 4           I agree  I am a developer by profession  25-34 years old
# 5           I agree  I am a developer by profession  25-34 years old
# 6           I agree  I am a developer by profession  35-44 years old
# ...             ...                             ...              ...
# 89176       I agree  I am a developer by profession  25-34 years old
# 89178       I agree  I am a developer by profession  35-44 years old
# 89179       I agree  I am a developer by profession  45-54 years old
# 89180       I agree  I am a developer by profession  25-34 years old
# 89184       I agree  I am a developer by profession  35-44 years old
#
#                                                    Employment  \
# ResponseId
# ...

# %%
df.loc[high_salary,['Country','LanguageHaveWorkedWith','CompTotal']]
# Out:
#                                                       Country  \
# ResponseId
# 2                                    United States of America
# 3                                    United States of America
# 4                                    United States of America
# 5                                                 Philippines
# 6           United Kingdom of Great Britain and Northern I...
# ...                                                       ...
# 89176                                United States of America
# 89178                                                  Mexico
# 89179                                United States of America
# 89180                                                  Brazil
# 89184                            Iran, Islamic Republic of...
#
#                                        LanguageHaveWorkedWith     CompTotal
# ResponseId
# 2                                  HTML/CSS;JavaScript;Python  2.850000e+05
# ...

# %%
countries = ['United States of America','India','Canada','Switzerland']
filt = df['Country'].isin(countries)

# %%
df.loc[filt]
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 2           I agree  I am a developer by profession     25-34 years old
# 3           I agree  I am a developer by profession     45-54 years old
# 4           I agree  I am a developer by profession     25-34 years old
# 7           I agree  I am a developer by profession     35-44 years old
# 8           I agree  I am a developer by profession     25-34 years old
# ...             ...                             ...                 ...
# 89166       I agree  I am a developer by profession     25-34 years old
# 89168       I agree  I am a developer by profession     18-24 years old
# 89176       I agree  I am a developer by profession     25-34 years old
# 89179       I agree  I am a developer by profession     45-54 years old
# 89183       I agree  I am a developer by profession  Under 18 years old
#
#                                         Employment  \
# ResponseId
# ...

# %%
df.loc[filt,'Country']
# Out:
# ResponseId
# 2        United States of America
# 3        United States of America
# 4        United States of America
# 7        United States of America
# 8        United States of America
#                    ...
# 89166                       India
# 89168                       India
# 89176    United States of America
# 89179    United States of America
# 89183                 Switzerland
# Name: Country, Length: 28928, dtype: object

# %%
lang = df['LanguageHaveWorkedWith'].str.contains('Python',na=False)

# %%
df.loc[lang]
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 2           I agree  I am a developer by profession     25-34 years old
# 8           I agree  I am a developer by profession     25-34 years old
# 10          I agree  I am a developer by profession     25-34 years old
# 11          I agree  I am a developer by profession     25-34 years old
# 12          I agree  I am a developer by profession     25-34 years old
# ...             ...                             ...                 ...
# 89173       I agree  I am a developer by profession     45-54 years old
# 89177       I agree  I am a developer by profession     18-24 years old
# 89181       I agree  I am a developer by profession     18-24 years old
# 89182       I agree     I code primarily as a hobby   Prefer not to say
# 89183       I agree  I am a developer by profession  Under 18 years old
#
#                                         Employment  \
# ResponseId
# ...

# %%
df.loc[lang,'LanguageHaveWorkedWith']
# Out:
# ResponseId
# 2                               HTML/CSS;JavaScript;Python
# 8        Go;HTML/CSS;JavaScript;Python;Rust;SQL;TypeScript
# 10          HTML/CSS;Java;JavaScript;Python;SQL;TypeScript
# 11                       C#;C++;HTML/CSS;JavaScript;Python
# 12       C#;HTML/CSS;JavaScript;Kotlin;PowerShell;Pytho...
#                                ...
# 89173    Bash/Shell (all shells);HTML/CSS;JavaScript;Pe...
# 89177    HTML/CSS;Java;JavaScript;PHP;Python;SQL;TypeSc...
# 89181                                 Dart;Java;Python;SQL
# 89182    Assembly;Bash/Shell (all shells);C;C#;Python;R...
# 89183    Bash/Shell (all shells);C#;HTML/CSS;Java;JavaS...
# Name: LanguageHaveWorkedWith, Length: 43158, dtype: object

# %% [markdown]
# # Updating rows and columns modifying data

# %%
df
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 1           I agree                   None of these     18-24 years old
# 2           I agree  I am a developer by profession     25-34 years old
# 3           I agree  I am a developer by profession     45-54 years old
# 4           I agree  I am a developer by profession     25-34 years old
# 5           I agree  I am a developer by profession     25-34 years old
# ...             ...                             ...                 ...
# 89180       I agree  I am a developer by profession     25-34 years old
# 89181       I agree  I am a developer by profession     18-24 years old
# 89182       I agree     I code primarily as a hobby   Prefer not to say
# 89183       I agree  I am a developer by profession  Under 18 years old
# 89184       I agree  I am a developer by profession     35-44 years old
#
#                                                    Employment  \
# ResponseId
# ...

# %%
df.rename(columns={'CompTotal':'SalaryUSD'},inplace=True)

# %%
df['SalaryUSD']
# Out:
# ResponseId
# 1                 NaN
# 2        2.850000e+05
# 3        2.500000e+05
# 4        1.560000e+05
# 5        1.320000e+06
#              ...
# 89180    2.000000e+05
# 89181             NaN
# 89182             NaN
# 89183             NaN
# 89184    3.300000e+09
# Name: SalaryUSD, Length: 89184, dtype: float64

# %%
df['CodingActivities']
# Out:
# ResponseId
# 1                                                      NaN
# 2        Hobby;Contribute to open-source projects;Boots...
# 3        Hobby;Professional development or self-paced l...
# 4                                                    Hobby
# 5        Hobby;Contribute to open-source projects;Profe...
#                                ...
# 89180    Hobby;Bootstrapping a business;Freelance/contr...
# 89181                              School or academic work
# 89182                                                  NaN
# 89183                        Hobby;School or academic work
# 89184    Hobby;Professional development or self-paced l...
# Name: CodingActivities, Length: 89184, dtype: object

# %% [markdown]
# # Add/Remove and Rows and Columns form DataFrames

# %%
df
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 1           I agree                   None of these     18-24 years old
# 2           I agree  I am a developer by profession     25-34 years old
# 3           I agree  I am a developer by profession     45-54 years old
# 4           I agree  I am a developer by profession     25-34 years old
# 5           I agree  I am a developer by profession     25-34 years old
# ...             ...                             ...                 ...
# 89180       I agree  I am a developer by profession     25-34 years old
# 89181       I agree  I am a developer by profession     18-24 years old
# 89182       I agree     I code primarily as a hobby   Prefer not to say
# 89183       I agree  I am a developer by profession  Under 18 years old
# 89184       I agree  I am a developer by profession     35-44 years old
#
#                                                    Employment  \
# ResponseId
# ...

# %% [markdown]
# # Sorting

# %%
df.sort_values(by="Country",inplace=True)

# %%
df[['Country','SalaryUSD']].head(100)
# Out:
#                 Country  SalaryUSD
# ResponseId
# 21498       Afghanistan        NaN
# 65293       Afghanistan        NaN
# 1335        Afghanistan   210000.0
# 33928       Afghanistan        NaN
# 77723       Afghanistan        NaN
# ...                 ...        ...
# 81712           Albania        NaN
# 83208           Albania        NaN
# 68259           Albania        NaN
# 1260            Albania   200000.0
# 40016           Albania        NaN
#
# [100 rows x 2 columns]

# %%
df.sort_values(by=["Country",'SalaryUSD'],ascending=[True,False],inplace=True)

# %%
df[['Country','SalaryUSD']].head(100)
# Out:
#                 Country    SalaryUSD
# ResponseId
# 88348       Afghanistan  932464379.0
# 1335        Afghanistan     210000.0
# 57362       Afghanistan     200000.0
# 17873       Afghanistan     100000.0
# 36049       Afghanistan      80000.0
# ...                 ...          ...
# 64157           Albania          NaN
# 64082           Albania          NaN
# 34271           Albania          NaN
# 19654           Albania          NaN
# 12813           Albania          NaN
#
# [100 rows x 2 columns]

# %%
  df["SalaryUSD"].nlargest(10)
# Out:
# ResponseId
# 56323    5.000000e+46
# 18464    1.000000e+21
# 43557    1.000000e+16
# 49554    1.000000e+16
# 35780    1.000000e+15
# 15440    4.567887e+12
# 33079    1.000000e+11
# 19680    2.239672e+10
# 56854    1.980000e+10
# 9176     1.840199e+10
# Name: SalaryUSD, dtype: float64

# %%
df.nlargest(10,"SalaryUSD")
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 56323       I agree                     I am a developer by profession
# 18464       I agree                     I am a developer by profession
# 43557       I agree                     I am a developer by profession
# 49554       I agree  I am not primarily a developer, but I write co...
# 35780       I agree                     I am a developer by profession
# 15440       I agree                     I am a developer by profession
# 33079       I agree                     I am a developer by profession
# 19680       I agree                     I am a developer by profession
# 56854       I agree  I am not primarily a developer, but I write co...
# 9176        I agree                     I am a developer by profession
#
#                         Age  \
# ResponseId
# 56323       25-34 years old
# 18464       25-34 years old
# 43557       18-24 years old
# 49554       25-34 years old
# ...

# %%
df["SalaryUSD"].nsmallest(10)
# Out:
# ResponseId
# 67794    0.0
# 59006    0.0
# 53788    0.0
# 4351     0.0
# 74558    0.0
# 51707    0.0
# 8984     0.0
# 88950    0.0
# 83555    0.0
# 10731    0.0
# Name: SalaryUSD, dtype: float64

# %%
df.nsmallest(10,"SalaryUSD")
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 67794       I agree                     I am a developer by profession
# 59006       I agree                     I am a developer by profession
# 53788       I agree                     I am a developer by profession
# 4351        I agree                     I am a developer by profession
# 74558       I agree  I am not primarily a developer, but I write co...
# 51707       I agree                     I am a developer by profession
# 8984        I agree  I am not primarily a developer, but I write co...
# 88950       I agree  I am not primarily a developer, but I write co...
# 83555       I agree                     I am a developer by profession
# 10731       I agree  I am not primarily a developer, but I write co...
#
#                           Age  \
# ResponseId
# 67794         18-24 years old
# 59006         35-44 years old
# 53788         35-44 years old
# 4351          18-24 years old
# ...

# %% [markdown]
# # Grouping and Aggregating - Analyzing and Exploration your Data

# %% [markdown]
# - combining multiple pieces of data into a single reult

# %% [markdown]
# - mean mode and median

# %%
df["SalaryUSD"].median()
# Out:
# 115000.0

# %%
df[["SalaryUSD","WorkExp"]].median()
# Out:
# SalaryUSD    115000.0
# WorkExp           9.0
# dtype: float64

# %%
df.median()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14248\530051474.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# SalaryUSD              115000.0
# WorkExp                     9.0
# ConvertedCompYearly     74963.0
# dtype: float64

# %%
df.describe()
# Out:
#           SalaryUSD       WorkExp  ConvertedCompYearly
# count  4.822500e+04  43579.000000         4.801900e+04
# mean   1.036807e+42     11.405126         1.031101e+05
# std    2.276847e+44      9.051989         6.814188e+05
# min    0.000000e+00      0.000000         1.000000e+00
# 25%    6.300000e+04      5.000000         4.390700e+04
# 50%    1.150000e+05      9.000000         7.496300e+04
# 75%    2.300000e+05     16.000000         1.216410e+05
# max    5.000000e+46     50.000000         7.435143e+07

# %%
df["SalaryUSD"]
# Out:
# ResponseId
# 88348    932464379.0
# 1335        210000.0
# 57362       200000.0
# 17873       100000.0
# 36049        80000.0
#             ...
# 88821            NaN
# 88829            NaN
# 88831            NaN
# 89029            NaN
# 89160            NaN
# Name: SalaryUSD, Length: 89184, dtype: float64

# %%
df["SalaryUSD"].count()
# Out:
# 48225

# %%
schema_df
# Out:
#                          qid  \
# qname
# AIAcc                 QID324
# AIBen                 QID316
# AIDev                 QID328
# AINext                QID320
# AIOpen                QID321
# AISearch              QID327
# AISelect              QID314
# AISent                QID315
# AITool                QID319
# Age                   QID127
# BuyNewTool            QID279
# CodingActivities      QID297
# CompTotal              QID51
# Country                 QID6
# Currency               QID50
# Database              QID262
# DevType                QID31
# EdLevel                QID25
# Employment            QID296
# Frequency             QID290
# Frequency_1           QID290
# Frequency_2           QID290
# Frequency_3           QID290
# ICorPM                QID287
# Industry              QID326
# Knowledge             QID289
# Knowledge_1           QID289
# Knowledge_2           QID289
# Knowledge_3           QID289
# Knowledge_4           QID289
# ...

# %%
schema_df.loc['WorkExp']
# Out:
# qid                                                      QID288
# question      How many years of working experience do you have?
# force_resp                                                False
# type                                                     Slider
# selector                                                HSLIDER
# Name: WorkExp, dtype: object

# %%
df['WorkExp'].count()
# Out:
# 43579

# %%
df['WorkExp'].value_counts()
# Out:
# 5.0     3299
# 10.0    3019
# 2.0     2796
# 3.0     2781
# 4.0     2529
# 7.0     2422
# 6.0     2329
# 1.0     2271
# 8.0     2232
# 15.0    2001
# 12.0    1719
# 20.0    1608
# 9.0     1425
# 11.0    1321
# 25.0    1202
# 13.0    1174
# 16.0     875
# 17.0     856
# 14.0     853
# 18.0     774
# 23.0     728
# 30.0     624
# 22.0     538
# 24.0     410
# 19.0     379
# 21.0     374
# 26.0     332
# 27.0     295
# 35.0     292
# 28.0     268
# 0.0      261
# 40.0     177
# 33.0     168
# 32.0     162
# 31.0     131
# 29.0     128
# 36.0     125
# 34.0     106
# 37.0      94
# 38.0      86
# 50.0      77
# 41.0      67
# 45.0      53
# 39.0      45
# 42.0      44
# 43.0      43
# 44.0      27
# 46.0      26
# 47.0      17
# 48.0      12
# 49.0       4
# Name: WorkExp, dtype: int64

# %%
df['TimeAnswering'].count()
# Out:
# 42629

# %%
df['TimeAnswering'].value_counts()
# Out:
# 15-30 minutes a day           13678
# 30-60 minutes a day           13013
# Less than 15 minutes a day     8321
# 60-120 minutes a day           5674
# Over 120 minutes a day         1943
# Name: TimeAnswering, dtype: int64

# %%
df['TimeSearching'].count()
# Out:
# 42778

# %%
df['TimeSearching'].value_counts()
# Out:
# 30-60 minutes a day           16338
# 15-30 minutes a day           11773
# 60-120 minutes a day           7626
# Less than 15 minutes a day     3959
# Over 120 minutes a day         3082
# Name: TimeSearching, dtype: int64

# %% [markdown]
# # groupby

# %% [markdown]
# - splitting the object, applying the function and comining the result

# %%
df['Country'].value_counts()
# Out:
# United States of America                                18647
# Germany                                                  7328
# India                                                    5625
# United Kingdom of Great Britain and Northern Ireland     5552
# Canada                                                   3507
#                                                         ...
# Grenada                                                     1
# Guinea-Bissau                                               1
# Liechtenstein                                               1
# Marshall Islands                                            1
# Saint Kitts and Nevis                                       1
# Name: Country, Length: 185, dtype: int64

# %%
df['Country'].value_counts(normalize = True)
# Out:
# United States of America                                0.211963
# Germany                                                 0.083298
# India                                                   0.063940
# United Kingdom of Great Britain and Northern Ireland    0.063110
# Canada                                                  0.039865
#                                                           ...
# Grenada                                                 0.000011
# Guinea-Bissau                                           0.000011
# Liechtenstein                                           0.000011
# Marshall Islands                                        0.000011
# Saint Kitts and Nevis                                   0.000011
# Name: Country, Length: 185, dtype: float64

# %%
country_grp = df.groupby(["Country"])

# %%
country_grp.get_group("India")
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 50306       I agree                     I am a developer by profession
# 15398       I agree                     I am a developer by profession
# 72666       I agree                     I am a developer by profession
# 86269       I agree  I am not primarily a developer, but I write co...
# 10000       I agree                     I am a developer by profession
# ...             ...                                                ...
# 77349       I agree                     I am a developer by profession
# 71267       I agree                     I am a developer by profession
# 57764       I agree                     I am a developer by profession
# 65424       I agree                     I am a developer by profession
# 51123       I agree                     I am a developer by profession
#
#                            Age  \
# ResponseId
# 50306          18-24 years old
# ...

# %%
country_grp.get_group("Germany")
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 14592       I agree  I am a developer by profession     35-44 years old
# 42983       I agree  I am a developer by profession     35-44 years old
# 67542       I agree  I am a developer by profession     35-44 years old
# 19091       I agree  I am a developer by profession     25-34 years old
# 16771       I agree  I am a developer by profession     25-34 years old
# ...             ...                             ...                 ...
# 4111        I agree  I am a developer by profession     18-24 years old
# 81238       I agree           I am learning to code  Under 18 years old
# 4036        I agree  I am a developer by profession     25-34 years old
# 52400       I agree  I am a developer by profession     35-44 years old
# 22598       I agree  I am a developer by profession     18-24 years old
#
#                                                    Employment  \
# ResponseId
# ...

# %%
# Traditional way 
filt = df["Country"] == "India"
df.loc[filt]
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 50306       I agree                     I am a developer by profession
# 15398       I agree                     I am a developer by profession
# 72666       I agree                     I am a developer by profession
# 86269       I agree  I am not primarily a developer, but I write co...
# 10000       I agree                     I am a developer by profession
# ...             ...                                                ...
# 77349       I agree                     I am a developer by profession
# 71267       I agree                     I am a developer by profession
# 57764       I agree                     I am a developer by profession
# 65424       I agree                     I am a developer by profession
# 51123       I agree                     I am a developer by profession
#
#                            Age  \
# ResponseId
# 50306          18-24 years old
# ...

# %%
filt = df["Country"] == "India"
df.loc[filt]["WorkExp"].value_counts()
# Out:
# 2.0     408
# 1.0     351
# 3.0     305
# 5.0     246
# 4.0     226
# 6.0     191
# 8.0     180
# 10.0    179
# 7.0     176
# 11.0    104
# 9.0      95
# 12.0     94
# 13.0     49
# 0.0      49
# 15.0     42
# 14.0     40
# 16.0     34
# 20.0     28
# 17.0     23
# 18.0     13
# 19.0     12
# 25.0     10
# 22.0      8
# 21.0      6
# 23.0      6
# 27.0      5
# 30.0      4
# 50.0      4
# 26.0      3
# 24.0      3
# 28.0      2
# 31.0      2
# 29.0      1
# 38.0      1
# 40.0      1
# Name: WorkExp, dtype: int64

# %%
country_grp["WorkExp"].value_counts().loc["India"]
# Out:
# WorkExp
# 2.0     408
# 1.0     351
# 3.0     305
# 5.0     246
# 4.0     226
# 6.0     191
# 8.0     180
# 10.0    179
# 7.0     176
# 11.0    104
# 9.0      95
# 12.0     94
# 0.0      49
# 13.0     49
# 15.0     42
# 14.0     40
# 16.0     34
# 20.0     28
# 17.0     23
# 18.0     13
# 19.0     12
# 25.0     10
# 22.0      8
# 21.0      6
# 23.0      6
# 27.0      5
# 30.0      4
# 50.0      4
# 24.0      3
# 26.0      3
# 28.0      2
# 31.0      2
# 29.0      1
# 38.0      1
# 40.0      1
# Name: WorkExp, dtype: int64

# %%
country_grp.get_group("Germany") #BaseGroupBy.get_group() missing 1 required positional argument: 'name'
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 14592       I agree  I am a developer by profession     35-44 years old
# 42983       I agree  I am a developer by profession     35-44 years old
# 67542       I agree  I am a developer by profession     35-44 years old
# 19091       I agree  I am a developer by profession     25-34 years old
# 16771       I agree  I am a developer by profession     25-34 years old
# ...             ...                             ...                 ...
# 4111        I agree  I am a developer by profession     18-24 years old
# 81238       I agree           I am learning to code  Under 18 years old
# 4036        I agree  I am a developer by profession     25-34 years old
# 52400       I agree  I am a developer by profession     35-44 years old
# 22598       I agree  I am a developer by profession     18-24 years old
#
#                                                    Employment  \
# ResponseId
# ...

# %%
country_grp["SalaryUSD"].median()
# Out:
# Country
# Afghanistan                                 62333.0
# Albania                                    104850.0
# Algeria                                    540000.0
# Andorra                                    120000.0
# Angola                                    2600000.0
#                                            ...
# Venezuela, Bolivarian Republic of...        14400.0
# Viet Nam                                200000000.0
# Yemen                                        9000.0
# Zambia                                      84000.0
# Zimbabwe                                    12500.0
# Name: SalaryUSD, Length: 185, dtype: float64

# %%
country_grp["SalaryUSD"].median().loc["India"]
# Out:
# 1450000.0

# %%
country_grp["SalaryUSD"].median().loc["India"]
# Out:
# 1450000.0

# %%
country_grp["SalaryUSD"].agg(['median','mean'])
# Out:
#                                            median          mean
# Country
# Afghanistan                               62333.0  6.666117e+07
# Albania                                  104850.0  1.185178e+06
# Algeria                                  540000.0  7.836667e+05
# Andorra                                  120000.0  1.562473e+09
# Angola                                  2600000.0  2.600000e+06
# ...                                           ...           ...
# Venezuela, Bolivarian Republic of...      14400.0  2.482463e+04
# Viet Nam                              200000000.0  3.287808e+08
# Yemen                                      9000.0  2.252071e+06
# Zambia                                    84000.0  1.507400e+05
# Zimbabwe                                  12500.0  2.674000e+04
#
# [185 rows x 2 columns]

# %%
country_grp["SalaryUSD"].agg(['median','mean']).loc["India"]
# Out:
# median    1.450000e+06
# mean      1.205815e+07
# Name: India, dtype: float64

# %%
filt = df["Country"] == "India"
df.loc[filt]["LanguageHaveWorkedWith"].str.contains("Python")
# Out:
# ResponseId
# 50306     True
# 15398    False
# 72666    False
# 86269     True
# 10000     True
#          ...
# 77349    False
# 71267    False
# 57764     True
# 65424    False
# 51123    False
# Name: LanguageHaveWorkedWith, Length: 5625, dtype: object

# %%
filt = df["Country"] == "India"
df.loc[filt]["LanguageHaveWorkedWith"].str.contains("Python").sum()
# Out:
# 2793

# %%
#country_grp["LanguageHaveWorkedWith"].str.contains("Python").sum()

# %%
country_grp["LanguageHaveWorkedWith"].apply(lambda x: x.str.contains("Python").sum() )
# Out:
# Country
# Afghanistan                              22
# Albania                                  19
# Algeria                                  35
# Andorra                                   5
# Angola                                    4
#                                        ...
# Venezuela, Bolivarian Republic of...     42
# Viet Nam                                174
# Yemen                                     8
# Zambia                                   11
# Zimbabwe                                 19
# Name: LanguageHaveWorkedWith, Length: 185, dtype: int64

# %%
country_responds=df["Country"].value_counts()
country_responds
# Out:
# United States of America                                18647
# Germany                                                  7328
# India                                                    5625
# United Kingdom of Great Britain and Northern Ireland     5552
# Canada                                                   3507
#                                                         ...
# Grenada                                                     1
# Guinea-Bissau                                               1
# Liechtenstein                                               1
# Marshall Islands                                            1
# Saint Kitts and Nevis                                       1
# Name: Country, Length: 185, dtype: int64

# %%
people_know_python_from_each_country=country_grp["LanguageHaveWorkedWith"].apply(lambda x: x.str.contains("Python").sum() )
people_know_python_from_each_country
# Out:
# Country
# Afghanistan                              22
# Albania                                  19
# Algeria                                  35
# Andorra                                   5
# Angola                                    4
#                                        ...
# Venezuela, Bolivarian Republic of...     42
# Viet Nam                                174
# Yemen                                     8
# Zambia                                   11
# Zimbabwe                                 19
# Name: LanguageHaveWorkedWith, Length: 185, dtype: int64

# %%
df_python = pd.concat([country_responds,people_know_python_from_each_country],axis='columns',sort=False)

# %%
df_python
# Out:
#                                                     Country  \
# United States of America                              18647
# Germany                                                7328
# India                                                  5625
# United Kingdom of Great Britain and Northern Ir...     5552
# Canada                                                 3507
# ...                                                     ...
# Grenada                                                   1
# Guinea-Bissau                                             1
# Liechtenstein                                             1
# Marshall Islands                                          1
# Saint Kitts and Nevis                                     1
#
#                                                     LanguageHaveWorkedWith
# United States of America                                             10062
# Germany                                                               3686
# ...

# %%
df_python.rename(columns={"Country":"NumberOfResponds","LanguageHaveWorkedWith":"NumberOfKnowsPython"},inplace=True)

# %%
df_python
# Out:
#                                                     NumberOfResponds  \
# United States of America                                       18647
# Germany                                                         7328
# India                                                           5625
# United Kingdom of Great Britain and Northern Ir...              5552
# Canada                                                          3507
# ...                                                              ...
# Grenada                                                            1
# Guinea-Bissau                                                      1
# Liechtenstein                                                      1
# Marshall Islands                                                   1
# Saint Kitts and Nevis                                              1
#
#                                                     NumberOfKnowsPython
# ...

# %%
df_python['pctOfPython'] = (df_python['NumberOfKnowsPython']/df_python['NumberOfResponds']) * 100

# %%
df_python
# Out:
#                                                     NumberOfResponds  \
# United States of America                                       18647
# Germany                                                         7328
# India                                                           5625
# United Kingdom of Great Britain and Northern Ir...              5552
# Canada                                                          3507
# ...                                                              ...
# Grenada                                                            1
# Guinea-Bissau                                                      1
# Liechtenstein                                                      1
# Marshall Islands                                                   1
# Saint Kitts and Nevis                                              1
#
#                                                     NumberOfKnowsPython  \
# ...

# %%
df_python.sort_values(by='pctOfPython',ascending=False)
# Out:
#                        NumberOfResponds  NumberOfKnowsPython  pctOfPython
# Saint Lucia                           2                    2        100.0
# Samoa                                 1                    1        100.0
# San Marino                            1                    1        100.0
# Grenada                               1                    1        100.0
# Liechtenstein                         1                    1        100.0
# ...                                 ...                  ...          ...
# Suriname                              4                    0          0.0
# Djibouti                              2                    0          0.0
# Monaco                                2                    0          0.0
# Gabon                                 2                    0          0.0
# Saint Kitts and Nevis                 1                    0          0.0
#
# [185 rows x 3 columns]

# %%
df_python
# Out:
#                                                     NumberOfResponds  \
# United States of America                                       18647
# Germany                                                         7328
# India                                                           5625
# United Kingdom of Great Britain and Northern Ir...              5552
# Canada                                                          3507
# ...                                                              ...
# Grenada                                                            1
# Guinea-Bissau                                                      1
# Liechtenstein                                                      1
# Marshall Islands                                                   1
# Saint Kitts and Nevis                                              1
#
#                                                     NumberOfKnowsPython  \
# ...

# %%
df_python.sort_values(by='pctOfPython',ascending=False,inplace = True)

# %%
df_python
# Out:
#                        NumberOfResponds  NumberOfKnowsPython  pctOfPython
# Saint Lucia                           2                    2        100.0
# Samoa                                 1                    1        100.0
# San Marino                            1                    1        100.0
# Grenada                               1                    1        100.0
# Liechtenstein                         1                    1        100.0
# ...                                 ...                  ...          ...
# Suriname                              4                    0          0.0
# Djibouti                              2                    0          0.0
# Monaco                                2                    0          0.0
# Gabon                                 2                    0          0.0
# Saint Kitts and Nevis                 1                    0          0.0
#
# [185 rows x 3 columns]

# %%
df_python.loc['India']
# Out:
# NumberOfResponds       5625.000000
# NumberOfKnowsPython    2793.000000
# pctOfPython              49.653333
# Name: India, dtype: float64

# %% [markdown]
# # Cleaning Data-Casting Datatypes and Handling Missing Values

# %%
df['YearsCode']
# Out:
# ResponseId
# 88348      8
# 1335       3
# 57362      4
# 17873      3
# 36049      5
#         ...
# 88821    NaN
# 88829    NaN
# 88831    NaN
# 89029    NaN
# 89160    NaN
# Name: YearsCode, Length: 89184, dtype: object

# %%
df['YearsCode'].value_counts()
# Out:
# 10                    6521
# 5                     5415
# 6                     4893
# 8                     4879
# 7                     4800
# 4                     4466
# 15                    4336
# 3                     4269
# 20                    4021
# 12                    3471
# 9                     3130
# 2                     2826
# 25                    2685
# 13                    2601
# 11                    2519
# 14                    2278
# 30                    2078
# 16                    1842
# 18                    1690
# 17                    1544
# 23                    1327
# 40                    1302
# 1                     1294
# 22                    1210
# 35                    1118
# Less than 1 year       968
# 24                     959
# 19                     826
# 21                     761
# 28                     715
# 27                     710
# 26                     706
# 33                     496
# 32                     444
# ...

# %%
#df['YearsCode'].mean()

# %%
#df['YearsCode'].astype(float)

# %%
df['YearsCode'].unique()
# Out:
# array(['8', '3', '4', '5', '10', 'More than 50 years', '15', '18', '30',
#        '25', '9', '20', '2', nan, '24', '1', '6', '16',
#        'Less than 1 year', '11', '35', '12', '7', '14', '17', '40', '21',
#        '13', '50', '26', '23', '34', '28', '38', '19', '22', '39', '36',
#        '32', '37', '33', '27', '45', '41', '29', '31', '42', '44', '46',
#        '47', '43', '48', '49'], dtype=object)

# %%
df['YearsCode'].replace('More than 50 years',51,inplace=True)

# %%
df['YearsCode'].unique()
# Out:
# array(['8', '3', '4', '5', '10', 51, '15', '18', '30', '25', '9', '20',
#        '2', nan, '24', '1', '6', '16', 'Less than 1 year', '11', '35',
#        '12', '7', '14', '17', '40', '21', '13', '50', '26', '23', '34',
#        '28', '38', '19', '22', '39', '36', '32', '37', '33', '27', '45',
#        '41', '29', '31', '42', '44', '46', '47', '43', '48', '49'],
#       dtype=object)

# %%
df['YearsCode'].replace('Less than 1 year',0,inplace=True)

# %%
df['YearsCode'].unique()
# Out:
# array(['8', '3', '4', '5', '10', 51, '15', '18', '30', '25', '9', '20',
#        '2', nan, '24', '1', '6', '16', 0, '11', '35', '12', '7', '14',
#        '17', '40', '21', '13', '50', '26', '23', '34', '28', '38', '19',
#        '22', '39', '36', '32', '37', '33', '27', '45', '41', '29', '31',
#        '42', '44', '46', '47', '43', '48', '49'], dtype=object)

# %%
df['YearsCode']=df['YearsCode'].astype(float)

# %%
df['YearsCode'].mean()
# Out:
# 13.966855378281009

# %%
df['YearsCode'].median()
# Out:
# 11.0

# %% [markdown]
# # Working with Dates and Time Series Data

# %%
import pandas as pd

# %%
df=pd.read_csv('ETH_1H.csv')

# %%
df
# Out:
#        Unix Timestamp                 Date  Symbol    Open    High     Low  \
# 0       1586995200000  2020-04-16 00:00:00  ETHUSD  152.94  152.94  150.39
# 1       1586991600000  2020-04-15 23:00:00  ETHUSD  155.81  155.81  151.39
# 2       1586988000000  2020-04-15 22:00:00  ETHUSD  157.18  157.30  155.32
# 3       1586984400000  2020-04-15 21:00:00  ETHUSD  158.04  158.31  157.16
# 4       1586980800000  2020-04-15 20:00:00  ETHUSD  157.10  158.10  156.87
# ...               ...                  ...     ...     ...     ...     ...
# 34492      1462813200  2016-05-09 17:00:00  ETHUSD    9.83    9.83    9.48
# 34493      1462809600  2016-05-09 16:00:00  ETHUSD    9.99    9.99    9.79
# 34494      1462806000  2016-05-09 15:00:00  ETHUSD   10.00   10.00    9.99
# 34495      1462802400  2016-05-09 14:00:00  ETHUSD    9.55   10.00    9.55
# 34496      1462798800  2016-05-09 13:00:00  ETHUSD    0.00   12.00    0.00
#
#         Close       Volume
# 0      150.39   650.188125
# ...

# %%
df.shape
# Out:
# (34497, 8)

# %%
df['Date'] # already in standard format
# Out:
# 0        2020-04-16 00:00:00
# 1        2020-04-15 23:00:00
# 2        2020-04-15 22:00:00
# 3        2020-04-15 21:00:00
# 4        2020-04-15 20:00:00
#                 ...
# 34492    2016-05-09 17:00:00
# 34493    2016-05-09 16:00:00
# 34494    2016-05-09 15:00:00
# 34495    2016-05-09 14:00:00
# 34496    2016-05-09 13:00:00
# Name: Date, Length: 34497, dtype: object

# %%
#df.loc[0,'Date'].day_name()

# %% [markdown]
# - but incase of yymmdd IP it will convert to yymmdd h format by providing original format='%Y-%m-%d %I-%p' to format='%Y-%m-%d %H

# %%
df['Date']=pd.to_datetime(df["Date"],format='%Y-%m-%d %H')

# %%
df['Date']
# Out:
# 0       2020-04-16 00:00:00
# 1       2020-04-15 23:00:00
# 2       2020-04-15 22:00:00
# 3       2020-04-15 21:00:00
# 4       2020-04-15 20:00:00
#                 ...
# 34492   2016-05-09 17:00:00
# 34493   2016-05-09 16:00:00
# 34494   2016-05-09 15:00:00
# 34495   2016-05-09 14:00:00
# 34496   2016-05-09 13:00:00
# Name: Date, Length: 34497, dtype: datetime64[ns]

# %%
df.loc[0,'Date'].day_name()
# Out:
# 'Thursday'

# %%
df.loc[0,'Date'].month_name()
# Out:
# 'April'

# %%
#df=pd.read_csv('ETH_1H.csv')

# %%
df["Date"].dt.day_name()
# Out:
# 0         Thursday
# 1        Wednesday
# 2        Wednesday
# 3        Wednesday
# 4        Wednesday
#            ...
# 34492       Monday
# 34493       Monday
# 34494       Monday
# 34495       Monday
# 34496       Monday
# Name: Date, Length: 34497, dtype: object

# %%
df["DayOfWeek"] = df["Date"].dt.day_name()

# %%
df
# Out:
#        Unix Timestamp                Date  Symbol    Open    High     Low  \
# 0       1586995200000 2020-04-16 00:00:00  ETHUSD  152.94  152.94  150.39
# 1       1586991600000 2020-04-15 23:00:00  ETHUSD  155.81  155.81  151.39
# 2       1586988000000 2020-04-15 22:00:00  ETHUSD  157.18  157.30  155.32
# 3       1586984400000 2020-04-15 21:00:00  ETHUSD  158.04  158.31  157.16
# 4       1586980800000 2020-04-15 20:00:00  ETHUSD  157.10  158.10  156.87
# ...               ...                 ...     ...     ...     ...     ...
# 34492      1462813200 2016-05-09 17:00:00  ETHUSD    9.83    9.83    9.48
# 34493      1462809600 2016-05-09 16:00:00  ETHUSD    9.99    9.99    9.79
# 34494      1462806000 2016-05-09 15:00:00  ETHUSD   10.00   10.00    9.99
# 34495      1462802400 2016-05-09 14:00:00  ETHUSD    9.55   10.00    9.55
# 34496      1462798800 2016-05-09 13:00:00  ETHUSD    0.00   12.00    0.00
#
#         Close       Volume  DayOfWeek
# 0      150.39   650.188125   Thursday
# ...

# %%
df['Date'].dt.month_name()
# Out:
# 0        April
# 1        April
# 2        April
# 3        April
# 4        April
#          ...
# 34492      May
# 34493      May
# 34494      May
# 34495      May
# 34496      May
# Name: Date, Length: 34497, dtype: object

# %%
df["Month"] =df['Date'].dt.month_name()

# %%
df
# Out:
#        Unix Timestamp                Date  Symbol    Open    High     Low  \
# 0       1586995200000 2020-04-16 00:00:00  ETHUSD  152.94  152.94  150.39
# 1       1586991600000 2020-04-15 23:00:00  ETHUSD  155.81  155.81  151.39
# 2       1586988000000 2020-04-15 22:00:00  ETHUSD  157.18  157.30  155.32
# 3       1586984400000 2020-04-15 21:00:00  ETHUSD  158.04  158.31  157.16
# 4       1586980800000 2020-04-15 20:00:00  ETHUSD  157.10  158.10  156.87
# ...               ...                 ...     ...     ...     ...     ...
# 34492      1462813200 2016-05-09 17:00:00  ETHUSD    9.83    9.83    9.48
# 34493      1462809600 2016-05-09 16:00:00  ETHUSD    9.99    9.99    9.79
# 34494      1462806000 2016-05-09 15:00:00  ETHUSD   10.00   10.00    9.99
# 34495      1462802400 2016-05-09 14:00:00  ETHUSD    9.55   10.00    9.55
# 34496      1462798800 2016-05-09 13:00:00  ETHUSD    0.00   12.00    0.00
#
#         Close       Volume  DayOfWeek  Month
# ...

# %%
df['Date'].min()
# Out:
# Timestamp('2016-05-09 13:00:00')

# %%
df['Date'].max()
# Out:
# Timestamp('2020-04-16 00:00:00')

# %%
df['Date'].max() - df['Date'].min()
# Out:
# Timedelta('1437 days 11:00:00')

# %%
filt = df['Date'] >='2016'

# %%
df.loc[filt]
# Out:
#        Unix Timestamp                Date  Symbol    Open    High     Low  \
# 0       1586995200000 2020-04-16 00:00:00  ETHUSD  152.94  152.94  150.39
# 1       1586991600000 2020-04-15 23:00:00  ETHUSD  155.81  155.81  151.39
# 2       1586988000000 2020-04-15 22:00:00  ETHUSD  157.18  157.30  155.32
# 3       1586984400000 2020-04-15 21:00:00  ETHUSD  158.04  158.31  157.16
# 4       1586980800000 2020-04-15 20:00:00  ETHUSD  157.10  158.10  156.87
# ...               ...                 ...     ...     ...     ...     ...
# 34492      1462813200 2016-05-09 17:00:00  ETHUSD    9.83    9.83    9.48
# 34493      1462809600 2016-05-09 16:00:00  ETHUSD    9.99    9.99    9.79
# 34494      1462806000 2016-05-09 15:00:00  ETHUSD   10.00   10.00    9.99
# 34495      1462802400 2016-05-09 14:00:00  ETHUSD    9.55   10.00    9.55
# 34496      1462798800 2016-05-09 13:00:00  ETHUSD    0.00   12.00    0.00
#
#         Close       Volume  DayOfWeek  Month
# ...

# %%
filt = (df['Date'] >='2016') & (df['Date'] <='2020')

# %%
df.loc[filt]
# Out:
#        Unix Timestamp                Date  Symbol    Open    High     Low  \
# 2544    1577836800000 2020-01-01 00:00:00  ETHUSD  128.84  128.84  128.07
# 2545    1577833200000 2019-12-31 23:00:00  ETHUSD  128.68  128.85  127.82
# 2546    1577829600000 2019-12-31 22:00:00  ETHUSD  128.40  128.93  127.77
# 2547    1577826000000 2019-12-31 21:00:00  ETHUSD  127.87  128.41  127.81
# 2548    1577822400000 2019-12-31 20:00:00  ETHUSD  127.86  128.30  127.86
# ...               ...                 ...     ...     ...     ...     ...
# 34492      1462813200 2016-05-09 17:00:00  ETHUSD    9.83    9.83    9.48
# 34493      1462809600 2016-05-09 16:00:00  ETHUSD    9.99    9.99    9.79
# 34494      1462806000 2016-05-09 15:00:00  ETHUSD   10.00   10.00    9.99
# 34495      1462802400 2016-05-09 14:00:00  ETHUSD    9.55   10.00    9.55
# 34496      1462798800 2016-05-09 13:00:00  ETHUSD    0.00   12.00    0.00
#
#         Close       Volume  DayOfWeek     Month
# ...

# %%
filt = (df['Date'] >=pd.to_datetime('2016-01-01')) & (df['Date'] <=pd.to_datetime('2020-02-01'))

# %%
df.loc[filt]
# Out:
#        Unix Timestamp                Date  Symbol    Open    High     Low  \
# 1800    1580515200000 2020-02-01 00:00:00  ETHUSD  179.75  181.20  179.15
# 1801    1580511600000 2020-01-31 23:00:00  ETHUSD  181.78  181.78  179.22
# 1802    1580508000000 2020-01-31 22:00:00  ETHUSD  180.69  182.28  180.57
# 1803    1580504400000 2020-01-31 21:00:00  ETHUSD  180.32  180.87  179.91
# 1804    1580500800000 2020-01-31 20:00:00  ETHUSD  178.99  180.59  178.99
# ...               ...                 ...     ...     ...     ...     ...
# 34492      1462813200 2016-05-09 17:00:00  ETHUSD    9.83    9.83    9.48
# 34493      1462809600 2016-05-09 16:00:00  ETHUSD    9.99    9.99    9.79
# 34494      1462806000 2016-05-09 15:00:00  ETHUSD   10.00   10.00    9.99
# 34495      1462802400 2016-05-09 14:00:00  ETHUSD    9.55   10.00    9.55
# 34496      1462798800 2016-05-09 13:00:00  ETHUSD    0.00   12.00    0.00
#
#         Close      Volume DayOfWeek     Month
# ...

# %%
df.set_index("Date",inplace=True)

# %%
df
# Out:
#                      Unix Timestamp  Symbol    Open    High     Low   Close  \
# Date
# 2020-04-16 00:00:00   1586995200000  ETHUSD  152.94  152.94  150.39  150.39
# 2020-04-15 23:00:00   1586991600000  ETHUSD  155.81  155.81  151.39  152.94
# 2020-04-15 22:00:00   1586988000000  ETHUSD  157.18  157.30  155.32  155.81
# 2020-04-15 21:00:00   1586984400000  ETHUSD  158.04  158.31  157.16  157.18
# 2020-04-15 20:00:00   1586980800000  ETHUSD  157.10  158.10  156.87  158.04
# ...                             ...     ...     ...     ...     ...     ...
# 2016-05-09 17:00:00      1462813200  ETHUSD    9.83    9.83    9.48    9.49
# 2016-05-09 16:00:00      1462809600  ETHUSD    9.99    9.99    9.79    9.83
# 2016-05-09 15:00:00      1462806000  ETHUSD   10.00   10.00    9.99    9.99
# 2016-05-09 14:00:00      1462802400  ETHUSD    9.55   10.00    9.55   10.00
# 2016-05-09 13:00:00      1462798800  ETHUSD    0.00   12.00    0.00    9.55
#
# ...

# %%
df['2019-1':'2019-12']
# Out:
#                      Unix Timestamp  Symbol    Open    High     Low   Close  \
# Date
# 2019-12-31 23:00:00   1577833200000  ETHUSD  128.68  128.85  127.82  128.84
# 2019-12-31 22:00:00   1577829600000  ETHUSD  128.40  128.93  127.77  128.68
# 2019-12-31 21:00:00   1577826000000  ETHUSD  127.87  128.41  127.81  128.40
# 2019-12-31 20:00:00   1577822400000  ETHUSD  127.86  128.30  127.86  127.87
# 2019-12-31 19:00:00   1577818800000  ETHUSD  128.78  128.78  127.86  127.86
# ...                             ...     ...     ...     ...     ...     ...
# 2019-01-01 04:00:00   1546315200000  ETHUSD  130.83  133.75  130.83  132.09
# 2019-01-01 03:00:00   1546311600000  ETHUSD  129.79  131.00  129.79  130.83
# 2019-01-01 02:00:00   1546308000000  ETHUSD  130.98  130.98  129.25  129.79
# 2019-01-01 01:00:00   1546304400000  ETHUSD  131.10  131.10  128.72  130.98
# 2019-01-01 00:00:00   1546300800000  ETHUSD  130.80  131.70  130.00  131.10
#
# ...

# %%
df['2019-1':'2019-12']['Close']
# Out:
# Date
# 2019-12-31 23:00:00    128.84
# 2019-12-31 22:00:00    128.68
# 2019-12-31 21:00:00    128.40
# 2019-12-31 20:00:00    127.87
# 2019-12-31 19:00:00    127.86
#                         ...
# 2019-01-01 04:00:00    132.09
# 2019-01-01 03:00:00    130.83
# 2019-01-01 02:00:00    129.79
# 2019-01-01 01:00:00    130.98
# 2019-01-01 00:00:00    131.10
# Name: Close, Length: 8757, dtype: float64

# %%
df['2019-1':'2019-12']['Close'].mean()
# Out:
# 180.78403905447072

# %%
df['2020-1':'2020-02'].head(24)
# Out:
#                      Unix Timestamp  Symbol    Open    High     Low   Close  \
# Date
# 2020-02-29 23:00:00   1583017200000  ETHUSD  222.93  223.96  217.26  217.35
# 2020-02-29 22:00:00   1583013600000  ETHUSD  223.59  223.76  222.32  222.93
# 2020-02-29 21:00:00   1583010000000  ETHUSD  224.81  225.08  223.05  223.59
# 2020-02-29 20:00:00   1583006400000  ETHUSD  225.56  225.56  223.55  224.81
# 2020-02-29 19:00:00   1583002800000  ETHUSD  225.05  225.92  224.06  225.56
# 2020-02-29 18:00:00   1582999200000  ETHUSD  225.37  225.99  224.65  225.05
# 2020-02-29 17:00:00   1582995600000  ETHUSD  222.94  225.39  222.27  225.37
# 2020-02-29 16:00:00   1582992000000  ETHUSD  225.43  226.06  222.43  222.94
# 2020-02-29 15:00:00   1582988400000  ETHUSD  223.31  226.04  221.66  225.43
# 2020-02-29 14:00:00   1582984800000  ETHUSD  224.32  224.32  221.17  223.31
# 2020-02-29 13:00:00   1582981200000  ETHUSD  225.66  225.66  223.07  224.32
# ...

# %%
df['2020-01-01']
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14248\15155530.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df['2020-01-01']
#                      Unix Timestamp  Symbol    Open    High     Low   Close  \
# Date
# 2020-01-01 23:00:00   1577919600000  ETHUSD  129.91  130.25  129.35  130.25
# 2020-01-01 22:00:00   1577916000000  ETHUSD  131.31  131.31  129.53  129.91
# 2020-01-01 21:00:00   1577912400000  ETHUSD  131.73  131.92  131.19  131.31
# 2020-01-01 20:00:00   1577908800000  ETHUSD  131.40  131.74  131.07  131.73
# 2020-01-01 19:00:00   1577905200000  ETHUSD  131.45  131.71  131.00  131.40
# 2020-01-01 18:00:00   1577901600000  ETHUSD  131.95  132.10  131.29  131.45
# 2020-01-01 17:00:00   1577898000000  ETHUSD  132.52  132.57  131.95  131.95
# ...

# %%
df['2020-01-01']['High']
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14248\1672683708.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df['2020-01-01']['High']
# Date
# 2020-01-01 23:00:00    130.25
# 2020-01-01 22:00:00    131.31
# 2020-01-01 21:00:00    131.92
# 2020-01-01 20:00:00    131.74
# 2020-01-01 19:00:00    131.71
# 2020-01-01 18:00:00    132.10
# 2020-01-01 17:00:00    132.57
# 2020-01-01 16:00:00    132.52
# 2020-01-01 15:00:00    131.86
# 2020-01-01 14:00:00    131.90
# 2020-01-01 13:00:00    131.59
# 2020-01-01 12:00:00    131.27
# 2020-01-01 11:00:00    131.46
# 2020-01-01 10:00:00    130.47
# 2020-01-01 09:00:00    130.23
# 2020-01-01 08:00:00    129.96
# 2020-01-01 07:00:00    130.35
# 2020-01-01 06:00:00    130.31
# 2020-01-01 05:00:00    129.92
# 2020-01-01 04:00:00    129.96
# 2020-01-01 03:00:00    130.30
# ...

# %%
df['2020-01-01']['High'].max()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14248\3485283041.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df['2020-01-01']['High'].max()
# 132.57

# %%
day_high=df["High"].resample("D").max()

# %%
day_high['2020-01-01']
# Out:
# 132.57

# %%
# %matplotlib inline

# %%
day_high.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df.resample('W').mean()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14248\243213992.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.resample('W').mean()
#             Unix Timestamp        Open        High         Low       Close  \
# Date
# 2016-05-15    1.463076e+09   10.140387   10.310516   10.052387   10.205290
# 2016-05-22    1.463657e+09   13.042262   13.144048   12.965179   13.066964
# 2016-05-29    1.464262e+09   12.481012   12.555536   12.385357   12.471012
# 2016-06-05    1.464867e+09   13.586369   13.651667   13.542202   13.594583
# 2016-06-12    1.465472e+09   14.287500   14.326190   14.260179   14.297798
# ...                    ...         ...         ...         ...         ...
# 2020-03-22    1.584617e+12  124.640952  126.387917  122.802262  124.636012
# ...

# %%
df.resample('W').agg({'High':'max',"Low":'min',"Volume":'sum'})
# Out:
#               High     Low         Volume
# Date
# 2016-05-15   12.00    0.00   10988.942273
# 2016-05-22   14.77   10.06   40673.495362
# 2016-05-29   14.43   10.41   58051.809091
# 2016-06-05   16.05   12.41   47351.544496
# 2016-06-12   15.75   13.83   52002.171838
# ...            ...     ...            ...
# 2020-03-22  153.17  100.70  439980.283707
# 2020-03-29  144.14  119.17  230941.584515
# 2020-04-05  150.32  124.09  151022.864981
# 2020-04-12  176.74  142.87  204715.937994
# 2020-04-19  162.15  150.12   50776.889638
#
# [206 rows x 3 columns]

# %%
df.resample('W').agg({'High':'max',"Low":'min',"Volume":'sum'}).plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # Reading/Writing Data to Different Sources like Excel,JSON,SQL,Etc

# %%
df=pd.read_csv("survey_results_public.csv")

# %%
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
df.set_index('ResponseId',inplace=True) # we can set index like this or while importing scv file
#df=pd.read_csv("survey_results_public.csv",index_col="ResponseId")

# %%
df.head()
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 1           I agree                   None of these  18-24 years old
# 2           I agree  I am a developer by profession  25-34 years old
# 3           I agree  I am a developer by profession  45-54 years old
# 4           I agree  I am a developer by profession  25-34 years old
# 5           I agree  I am a developer by profession  25-34 years old
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# 3                                         Employed, full-time
# 4                                         Employed, full-time
# 5           Employed, full-time;Independent contractor, fr...
#
#                                       RemoteWork  \
# ResponseId
# 1                                            NaN
# ...

# %%
filt = df["Country"] == "India"

# %%
india_df = df.loc[filt]

# %%
india_df.head()
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 10          I agree  I am a developer by profession  25-34 years old
# 67          I agree  I am a developer by profession  25-34 years old
# 79          I agree  I am a developer by profession  18-24 years old
# 83          I agree  I am a developer by profession  25-34 years old
# 86          I agree  I am a developer by profession  25-34 years old
#
#                                     Employment  \
# ResponseId
# 10          Not employed, but looking for work
# 67                         Employed, full-time
# 79                         Employed, full-time
# 83                         Employed, full-time
# 86                         Employed, full-time
#
#                                       RemoteWork  \
# ResponseId
# 10                                           NaN
# 67          Hybrid (some remote, some in-person)
# 79                                        Remote
# ...

# %%
india_df.to_csv('modified.csv')

# %%
india_df.to_csv('modified.tsv',sep='\t')

# %%
pd.read_csv('modified.tsv',sep='\t')
# Out:
#       ResponseId     Q120                                         MainBranch  \
# 0             10  I agree                     I am a developer by profession
# 1             67  I agree                     I am a developer by profession
# 2             79  I agree                     I am a developer by profession
# 3             83  I agree                     I am a developer by profession
# 4             86  I agree                     I am a developer by profession
# ...          ...      ...                                                ...
# 5620       89120  I agree                     I am a developer by profession
# 5621       89122  I agree  I am not primarily a developer, but I write co...
# 5622       89165  I agree                     I am a developer by profession
# 5623       89166  I agree                     I am a developer by profession
# 5624       89168  I agree                     I am a developer by profession
#
# ...

# %%
india_df.to_excel('modified.xlsx')

# %%
pd.read_excel('modified.xlsx',index_col="ResponseId")

# %%
india_df.to_json("modified.json",orient='records',lines=True)#india_df.to_json("modified.json")

# %%
pd.read_json('modified.json',orient='records',lines=True)
# Out:
#          Q120                                         MainBranch  \
# 0     I agree                     I am a developer by profession
# 1     I agree                     I am a developer by profession
# 2     I agree                     I am a developer by profession
# 3     I agree                     I am a developer by profession
# 4     I agree                     I am a developer by profession
# ...       ...                                                ...
# 5620  I agree                     I am a developer by profession
# 5621  I agree  I am not primarily a developer, but I write co...
# 5622  I agree                     I am a developer by profession
# 5623  I agree                     I am a developer by profession
# 5624  I agree                     I am a developer by profession
#
#                   Age                              Employment  \
# 0     25-34 years old      Not employed, but looking for work
# ...

# %%
from sqlalchemy import create_engine

# %%
from getpass import getpass

password = getpass()

# %%
engine = create_engine('mysql+pymysql://root:{}@localhost:3306/stackoverflow'.format(password))

# %%
india_df.to_sql('sample_table',engine)
